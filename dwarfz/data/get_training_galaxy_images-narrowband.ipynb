# %%
# give access to importing dwarfz
import os, sys
dwarfz_package_dir = os.getcwd().split("dwarfz")[0]
if dwarfz_package_dir not in sys.path:
    sys.path.insert(0, dwarfz_package_dir)

import dwarfz
    
# back to regular import statements

# %matplotlib inline
from matplotlib import pyplot as plt

import seaborn as sns
sns.set(context="poster", style="ticks", font_scale=1.4)

import numpy as np
import pandas as pd
import glob
import shutil

from scipy.special import expit
import pathlib

import send2trash

# %%
COSMOS_filename = pathlib.Path(dwarfz.data_dir_default) / "COSMOS_reference.sqlite"
COSMOS = dwarfz.datasets.COSMOS(COSMOS_filename)

# %%
HSC_filename = pathlib.Path(dwarfz.data_dir_default) / "HSC_COSMOS_median_forced.sqlite3"
HSC = dwarfz.datasets.HSC(HSC_filename)

# %%
matches_filename = pathlib.Path(dwarfz.data_dir_default) / "matches.sqlite3"
matches_df = dwarfz.matching.Matches.load_from_filename(matches_filename)

# %%
combined = matches_df[matches_df.match].copy()
combined["ra"]       = COSMOS.df.loc[combined.index].ra
combined["dec"]      = COSMOS.df.loc[combined.index].dec
combined["photo_z"]  = COSMOS.df.loc[combined.index].photo_z
combined["log_mass"] = COSMOS.df.loc[combined.index].mass_med

photometry_cols = [
    "gcmodel_flux","gcmodel_flux_err","gcmodel_flux_flags", "gcmodel_mag",
    "rcmodel_flux","rcmodel_flux_err","rcmodel_flux_flags", "rcmodel_mag",
    "icmodel_flux","icmodel_flux_err","icmodel_flux_flags", "icmodel_mag",
    "zcmodel_flux","zcmodel_flux_err","zcmodel_flux_flags", "zcmodel_mag",
    "ycmodel_flux","ycmodel_flux_err","ycmodel_flux_flags", "ycmodel_mag",
]

for col in photometry_cols:
    combined[col] = HSC.df.loc[combined.catalog_2_ids][col].values

# %% [markdown]
# ## Turn magnitudes into colors

# %%
combined["g_minus_r"] = combined.gcmodel_mag - combined.rcmodel_mag
combined["r_minus_i"] = combined.rcmodel_mag - combined.icmodel_mag
combined["i_minus_z"] = combined.icmodel_mag - combined.zcmodel_mag
combined["z_minus_y"] = combined.zcmodel_mag - combined.ycmodel_mag

# %% [markdown]
# ## Filter out bad data

# %%
mask =    np.isfinite(combined["g_minus_r"]) & np.isfinite(combined["r_minus_i"]) \
        & np.isfinite(combined["i_minus_z"]) & np.isfinite(combined["z_minus_y"]) \
        & np.isfinite(combined["icmodel_mag"]) \
        & (~combined.gcmodel_flux_flags) & (~combined.rcmodel_flux_flags) \
        & (~combined.icmodel_flux_flags) & (~combined.zcmodel_flux_flags) \
        & (~combined.ycmodel_flux_flags)

combined = combined[mask]

# %% [markdown]
# # Create classification labels

# %%
low_z    = (combined.photo_z  < .15)
low_mass = (combined.log_mass > 8) & (combined.log_mass < 9)

# %%
combined["low_z_low_mass"] = (low_z & low_mass)
combined.low_z_low_mass.mean()
# Out:
# 0.002185072976027315

# %% [markdown]
# # Load the IDs of the narrowband population

# %%
target_ids = pd.read_csv("../narrowband_deconfusion/target_galaxies-HSC_ids.csv")
target_ids.head()
# Out:
#    COSMOS_id             HSC_id
# 0     219965  43158447025312151
# 1     220286  43158584464277542
# 2     220319  43158584464268517
# 3     220421  43158447025292549
# 4     220691  43158584464268544

# %%
contaminant_ids = pd.read_csv("../narrowband_deconfusion/contaminant_galaxies-HSC_ids.csv")
contaminant_ids.head()
# Out:
#    COSMOS_id             HSC_id
# 0     220029  43158584464246406
# 1     220142  43158859342153228
# 2     220169  43158859342173270
# 3     220274  43158447025298878
# 4     220476  43158721903220831

# %% [markdown]
# # Setup locations of images

# %%
targets_path = pathlib.Path.home() / "dwarfz" \
                                   / "galaxies_narrowband" \
                                   / "target"
targets_path.mkdir(parents=True, exist_ok=True)

# %%
contaminants_path = pathlib.Path.home() / "dwarfz" \
                                        / "galaxies_narrowband" \
                                        / "contaminant"
contaminants_path.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# # Copy over pre-downloaded images

# %%
google_dir = pathlib.Path.home() / "Google Drive" \
                                 / "HSC_COSMOS_galaxies" \
                                 / "galaxies"

predownloaded_ids = {int(image_dir.name)
                     for image_dir in google_dir.iterdir()
                     if image_dir.is_dir()}

# %%
i = 0

for (_, _, HSC_id) in target_ids.itertuples():
    if HSC_id in predownloaded_ids:
        image_dir = google_dir / str(HSC_id)
        new_dir = targets_path / image_dir.name
        if not new_dir.is_dir():
            new_dir.symlink_to(image_dir, target_is_directory=True)
        i += 1
        
print("symlinked {} galaxies".format(i))
# Out:
# symlinked 4162 galaxies

# %%
j = 0

for (_, _, HSC_id) in contaminant_ids.itertuples():
    if HSC_id in predownloaded_ids:
        image_dir = google_dir / str(HSC_id)
        new_dir = contaminants_path / image_dir.name
        if not new_dir.is_dir():
            new_dir.symlink_to(image_dir, target_is_directory=True)
        j += 1
        
print("symlinked {} galaxies".format(j))
# Out:
# symlinked 11256 galaxies

# %%
# num galaxies remaining to download
target_ids.shape[0] + contaminant_ids.shape[0] - i - j
# Out:
# 11521

# %%
target_ids_to_download = set(target_ids.HSC_id) - predownloaded_ids

# %%
contaminant_ids_to_download = set(contaminant_ids.HSC_id) - predownloaded_ids

# %%
ids_to_download = target_ids_to_download |  contaminant_ids_to_download

# %% [markdown]
# # Get the images from the quarry
#
# For technical details, see: https://hsc-release.mtk.nao.ac.jp/das_quarry/manual.html

# %% [markdown]
# I'll be downloading these directly into the google drive folder. Then, when everything is complete, I'll just symlink them into the appropriate project folders, split by target and contaminant.

# %% [markdown]
# ## Create a coordinates list

# %%
galaxy_coords = combined[["catalog_2_ids", "ra", "dec"]]
galaxy_coords = galaxy_coords.rename(columns={"catalog_2_ids":"HSC_index"})
galaxy_coords = galaxy_coords.set_index("HSC_index")
galaxy_coords = galaxy_coords.loc[ids_to_download]
galaxy_coords.head()
# Out:
#                            ra       dec
# HSC_index
# 43158597349179408  150.235849  2.280739
# 43159013961007125  149.604142  2.505246
# 43158876522053655  149.782530  2.485514
# 43158597349179418  150.263496  2.281219
# 43158872227086362  149.864641  2.318558

# %%
width = "20asec"
filters = ["HSC-G", "HSC-R", "HSC-I", "HSC-Z", "HSC-Y"]
rerun = "pdr1_deep"

# %%
quarry_input_dir = pathlib.Path("galaxy_images_training") \
    / "quarry_input_files"
quarry_input_dir.mkdir(exist_ok=True)
quarry_name_format = "tmp_quarry_{:>04d}.txt"

batch_i = 0
files_in_batch = 0

max_files_per_batch = 1000

tmp_filename = quarry_input_dir / quarry_name_format.format(batch_i)
f = open(tmp_filename, mode="w")
print("#?     ra          dec       filter   sw      sh      rerun", file=f)


print_formatter = " {galaxy.ra:.6f}deg  {galaxy.dec:.6f}deg  {filter}  {width}  {width}  {rerun} # {galaxy.Index}"
for galaxy in galaxy_coords.itertuples():
    for filter in filters:            
        print(print_formatter.format(galaxy=galaxy,
                                     width=width,
                                     filter=filter,
                                     rerun=rerun),
              file=f)
        files_in_batch += 1
        if files_in_batch == max_files_per_batch:
            f.close()
            files_in_batch = 0
            batch_i += 1
            tmp_filename = quarry_input_dir / quarry_name_format.format(batch_i)
            f = open(tmp_filename, mode="w")
            print("#?     ra          dec       filter   sw      sh      rerun", file=f)


f.close()

# %%
# !head -n 10 $tmp_filename
# Out:
# #?     ra          dec       filter   sw      sh      rerun
#  150.358331deg  2.680556deg  HSC-G  20asec  20asec  pdr1_deep # 43158468500160068
#  150.358331deg  2.680556deg  HSC-R  20asec  20asec  pdr1_deep # 43158468500160068
#  150.358331deg  2.680556deg  HSC-I  20asec  20asec  pdr1_deep # 43158468500160068
#  150.358331deg  2.680556deg  HSC-Z  20asec  20asec  pdr1_deep # 43158468500160068
#  150.358331deg  2.680556deg  HSC-Y  20asec  20asec  pdr1_deep # 43158468500160068
#  150.144028deg  2.269632deg  HSC-G  20asec  20asec  pdr1_deep # 43158734788132421
#  150.144028deg  2.269632deg  HSC-R  20asec  20asec  pdr1_deep # 43158734788132421
#  150.144028deg  2.269632deg  HSC-I  20asec  20asec  pdr1_deep # 43158734788132421
#  150.144028deg  2.269632deg  HSC-Z  20asec  20asec  pdr1_deep # 43158734788132421

# %%
# !wc -l $tmp_filename
# Out:
#      716 galaxy_images_training/quarry_input_files/tmp_quarry_0057.txt

# %%
# !ls  galaxy_images_training/quarry_input_files/ | wc -l
# Out:
#       58

# %%
# !ls -lh galaxy_images_training/quarry_input_files/ | head -n 10
# Out:
# total 9696
# -rw-r--r--@ 1 egentry  staff    80K Apr  4 14:05 tmp_quarry_0000.txt
# -rw-r--r--@ 1 egentry  staff    80K Apr  4 14:05 tmp_quarry_0001.txt
# -rw-r--r--@ 1 egentry  staff    80K Apr  4 14:05 tmp_quarry_0002.txt
# -rw-r--r--@ 1 egentry  staff    80K Apr  4 14:05 tmp_quarry_0003.txt
# -rw-r--r--@ 1 egentry  staff    80K Apr  4 14:05 tmp_quarry_0004.txt
# -rw-r--r--@ 1 egentry  staff    80K Apr  4 14:05 tmp_quarry_0005.txt
# -rw-r--r--@ 1 egentry  staff    80K Apr  4 14:05 tmp_quarry_0006.txt
# -rw-r--r--@ 1 egentry  staff    80K Apr  4 14:05 tmp_quarry_0007.txt
# -rw-r--r--@ 1 egentry  staff    80K Apr  4 14:05 tmp_quarry_0008.txt

# %% [markdown]
# ###  Make the request via curl
#
# 1)
#
# First you need to setup you authentication information. Add it to a file like `galaxy_images_training/curl_netrc` which should look like:
# ```machine hsc-release.mtk.nao.ac.jp login <your username> password <your password>```
# This allows you to script the curl calls, without being prompted for your password each time
#
# 2a)
#
# The `curl` call (in (2b)) will spit out files into a somewhat unpredicatably named directory, like `arch-170928-231223`. You should rename this to match the batch suffix. You *really should* do this right away, so you don't get confused. In general I add the rename onto the same line as the curl call:
# ``` curl ... | tar xvf - && mv arch-* quarry_files_a     ```
#
# This only works if it finds one `arch-` directory, but you *really* shouldn't have multiple arch directories at any given time; that's a recipe for getting your galaxies mixed up.
#
# 2b)
#
# Here's the actual curl invocation:
#
# ``` curl --netrc-file galaxy_images_training/curl_netrc https://hsc-release.mtk.nao.ac.jp/das_quarry/cgi-bin/quarryImage --form list=@<coord list filename> | tar xvf -     ```

# %%
filenames = sorted(quarry_input_dir.iterdir())

min_batch_number_to_pull = 1
max_batch_number_to_pull = 100

new_data_dir = targets_path.parent / "staging"

new_data_dir.mkdir(exist_ok=True)

for i, filename in enumerate(filenames):
    if i < min_batch_number_to_pull: 
        continue
    if i >= max_batch_number_to_pull:
        break

    print("Currently processing file: {}".format(os.path.basename(filename)), end="\r", flush=True)

    os.system(("curl -k --netrc-file galaxy_images_training/curl_netrc "
               "https://hsc-release.mtk.nao.ac.jp/das_quarry/cgi-bin/quarryImage "
               "--form list=@{filename} "
               "| tar -xvf -").format(filename=filename))


    arch_dirs = list(pathlib.Path.cwd().glob("arch-*"))
    assert(len(arch_dirs)==1)
    arch_dir = arch_dirs[0]
    with open(filename, "r") as f:
        _ = f.readline() # skip header
        line_number = 1 # 1 indexed, and then also with header
        for line in f:
            line_number += 1
            HSC_id = int(line.split("#")[-1].strip())
            HSC_dir = new_data_dir / str(HSC_id)
            HSC_dir.mkdir(exist_ok=True)
            

            image_filenames = list(arch_dir.glob( 
                str(line_number) + "-cutout-HSC-?-????-pdr1_deep.fits"
            ))
            
            if len(image_filenames) == 0:
                continue
            elif len(image_filenames) >1:
                raise RuntimeError("Too many files for line {} id {}".format(
                    line_number, HSC_id,
                ))
            image_filename = image_filenames[0]
            
            # rename with HSC id and move to within `new_data_dir`
            image_filename.rename(
                HSC_dir / image_filename.name.replace(
                    "{}-cutout".format(line_number),
                    "{}-cutout".format(HSC_id),
                )
            )
            

    arch_dir.rmdir()
# Out:
# Currently processing file: tmp_quarry_0057.txt

# %% [markdown]
# # Remove incomplete dirs, then transfer to main google drive directory

# %%
staging_dir = google_dir.parent / "staging"

# %%
num_removed = 0
for staged_dir in staging_dir.iterdir():
    if not staged_dir.is_dir(): continue
    
    num_images = len({*staged_dir.glob("*.fits")})
    if num_images>5:
        raise ValueError("{} has {} fits files".format(staged_dir, num_images))
    elif num_images < 5:
        print("too few images in {} (n={}); removing".format(
            staged_dir,
            num_images,
        ))
        num_removed += 1
        send2trash.send2trash(str(staged_dir))
    else:
        staged_dir.rename(staged_dir.parent.parent / "galaxies" / staged_dir.name)

num_removed
# Out:
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788101886 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788108305 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788132862 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349177253 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788102056 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349172177 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349179933 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349148648 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349177095 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788136297 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788109486 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349170872 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349157806 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158743378057333 (n=0); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349152583 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788110938 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788134365 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349155560 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349176386 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788104194 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158996781127857 (n=0); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788135078 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349171708 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349175952 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349171398 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349155790 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349181179 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788106057 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349151102 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349148813 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349174413 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788103387 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349155936 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349181989 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788108101 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349181141 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788109671 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788131289 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349178649 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788124764 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349181942 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349150245 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788107310 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349170642 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349172327 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788110195 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349150413 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349181788 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349148418 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349147662 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349181916 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349174216 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349177800 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788125629 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349170817 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349172318 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158730493165993 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349173468 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158867932108953 (n=0); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158610234071156 (n=0); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788125281 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788130105 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788129028 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349153265 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349175561 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349153291 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788127522 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349170477 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788125275 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349154843 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349175798 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349178087 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349181112 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349175308 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349182551 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788130133 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788111082 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788101022 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349150280 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43159138515048473 (n=0); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788131471 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349158019 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349173492 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788102005 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788134567 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349174218 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788126855 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349175568 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349152372 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788133577 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788107928 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788129489 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788105485 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788130908 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349177836 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349179958 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158472795117786 (n=0); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788132836 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788129670 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349149130 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788107148 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349173630 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788106607 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349173254 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788134167 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349175533 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349178442 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349176148 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788104954 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349174875 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349147865 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349170274 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788133721 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349150217 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349155765 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788107342 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349151331 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349176513 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349177899 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349173068 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349155798 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788130965 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788109641 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349177890 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788134364 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349172515 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349182169 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349154827 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788132609 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788132863 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349175962 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788130505 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788103515 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788106631 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788127122 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788125023 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788101084 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788107141 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788126262 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788129824 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788105014 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788127176 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349179501 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788132837 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788106830 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349180838 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349180004 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349182753 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349157068 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349175936 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349148080 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788133549 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349177837 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788131642 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788133327 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158193622243452 (n=0); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349157434 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788101675 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349174226 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349154621 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788125084 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788128334 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788135482 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349177237 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788133775 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158464205183157 (n=0); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349177005 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788105673 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788132839 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349173035 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158867932108952 (n=0); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788132653 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788107786 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349150872 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158880817010749 (n=0); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349158647 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788129224 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158885111978136 (n=0); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349176920 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349177698 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788132806 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349152183 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788134791 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788100796 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349153607 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349147035 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349148841 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788103745 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349148089 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349172326 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349149369 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158455615248585 (n=0); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788105022 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788102035 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158885111978131 (n=0); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349158486 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349157910 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788132987 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158472795117637 (n=0); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349175872 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788109590 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158318176295086 (n=0); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43159151399950534 (n=0); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788106974 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788110811 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349174954 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788133432 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788100610 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788134425 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788130415 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788126742 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349153547 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788124471 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788126326 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788131391 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788105998 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788109107 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349158197 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349176852 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349179214 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158601644136109 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788130076 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788110643 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349148934 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788133297 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788127451 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349172637 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788107432 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788129360 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349151448 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349148101 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349148333 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349175843 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349173986 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788111308 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158451320281189 (n=0); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158605939103825 (n=0); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349152696 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788132717 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788102176 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788133403 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349149018 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349178131 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349175078 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349178767 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788130844 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349179225 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349150132 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349176094 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788107631 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349150556 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788103057 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788110440 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788104424 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349174353 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349158199 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349155686 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349175221 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349152631 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788111156 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788133450 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349170337 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349171211 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349179418 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158867932108845 (n=0); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349158106 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788100827 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788132549 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349176837 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349154363 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349174556 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158863637141612 (n=0); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788127265 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788125700 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349177327 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349172655 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349176830 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43159155694917835 (n=0); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349149073 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788109191 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349172458 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788103200 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788102584 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349147114 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349174938 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349171644 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349157140 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349180910 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788127253 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158747673024631 (n=0); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158472795117690 (n=0); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788111990 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349178530 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349158137 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349180321 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788134227 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788128678 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788105560 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788111160 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788129598 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349178705 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349172831 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788125964 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788109392 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349178537 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349177927 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158322471262344 (n=0); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788130228 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349147973 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349181435 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788131399 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158459910215719 (n=0); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349153789 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349180345 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349178554 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349177381 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788130046 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158730493166007 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349147170 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349154593 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349147184 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788135998 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788109598 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349170150 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349158968 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788128075 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788134618 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349179475 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349153548 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788101953 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788107405 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788130889 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349171415 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788135157 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349181855 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349151220 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788105194 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158872227060682 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788127837 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349157916 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349180374 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349178757 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349154569 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349171078 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788124448 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349150102 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349151686 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349148599 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788101730 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788105390 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788124221 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349151024 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349176068 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43159155694917851 (n=0); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349173942 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349158959 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349157549 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349176433 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788134286 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788132343 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158601644136130 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349176265 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349148758 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349157744 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349177171 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788134616 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788111195 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788126717 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349176003 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349173743 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788106546 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788132773 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158451320281126 (n=0); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349177125 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158863637141622 (n=0); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788133655 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788133003 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788126942 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349179074 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788134689 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788110844 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788111962 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349155844 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349172468 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788133838 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788132774 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788130023 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349171645 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788135909 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788131308 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788129793 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349174906 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788109360 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349173549 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349179073 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349181662 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788109536 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788131133 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788102123 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349150736 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158863637141613 (n=0); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43159138515048555 (n=0); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349174765 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788134687 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788108270 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788125168 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349182025 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158996781127779 (n=0); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349174550 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158872227077454 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788105557 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349172461 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788102918 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788125706 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788106584 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349147927 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349180781 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349151628 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349152059 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349172806 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349151860 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788129774 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788132932 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788128652 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788102905 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349176641 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349156410 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788135770 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788125724 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349181488 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788107646 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788106794 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788127241 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788134656 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349177109 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349180106 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349178525 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349178717 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349148182 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788134038 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788109374 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349149296 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349174778 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788108863 (n=3); removing
# ...
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158601644136091 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158747673006466 (n=0); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788104310 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349150296 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349153873 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349180483 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349178602 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349173221 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349176561 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349157888 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349179971 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349151727 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349178857 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788131004 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349150433 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349177675 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788133337 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788125060 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788133939 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349150298 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788129462 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349151944 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788106811 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158730493155348 (n=0); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349154852 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788130319 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788108715 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349174664 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788108188 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349157082 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349152504 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788127157 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788128127 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788125638 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349181560 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349171578 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788125607 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788126082 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788134775 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788131663 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349149379 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349153425 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788101230 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788128588 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349179923 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788111697 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349153446 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788107396 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788133391 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158739083088178 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788111207 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788133157 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349171386 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43159018255964247 (n=0); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349148693 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349176396 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788127908 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788107365 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43159138515048605 (n=0); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349151124 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788110928 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158876522043612 (n=0); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349174263 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349153025 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349147425 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788126012 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349150459 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788130974 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788103158 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349181352 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788125231 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349150662 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788134515 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158863637141581 (n=0); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349181169 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349155579 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349174890 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788134986 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788132629 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349179111 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349148804 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349179915 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788135606 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788125838 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349153484 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349176708 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349179572 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158743378057312 (n=0); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788127308 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788108747 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158322471262227 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349170853 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788126874 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788103901 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349180023 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349182546 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788108145 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349173211 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788126245 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788134780 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43159005371062456 (n=0); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43159009666029726 (n=0); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788107300 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788127169 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349175318 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349150299 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158730493155349 (n=0); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788128748 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788130585 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788135493 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788130327 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788126242 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158885111978118 (n=0); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349151710 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158335356164124 (n=0); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349151146 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349171541 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788107900 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788131208 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788102218 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788110729 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788108180 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788125298 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788125896 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788132821 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788133104 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349170697 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788129658 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788124711 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43159018255964213 (n=0); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158610234071148 (n=0); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788124729 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349174459 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349170831 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788105806 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349180829 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788107309 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788134917 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349175927 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349171114 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788135032 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349173015 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349177673 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788124988 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158734788105461 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43159005371062460 (n=0); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349157422 (n=3); removing
# too few images in /Users/egentry/Google Drive/HSC_COSMOS_galaxies/staging/43158597349177217 (n=3); removing
# 1655

# %% [markdown]
# # Now link these new images to the project data directory

# %%
pre_linked_ids  = {int(path.name) for path in contaminants_path.iterdir() if path.is_dir()} 
pre_linked_ids |= {int(path.name) for path in targets_path.iterdir() if path.is_dir()} 
len(pre_linked_ids)
# Out:
# 15413

# %%
narrowband_ids = set(target_ids.HSC_id) | set(contaminant_ids.HSC_id)
len(narrowband_ids)
# Out:
# 26934

# %%
all_downloaded_ids = {int(path.name) for path in google_dir.iterdir()
                      if path.is_dir()}
len(all_downloaded_ids)
# Out:
# 183278

# %%
num_to_link = 0
already_linked = 0
missing = 0
for HSC_id in narrowband_ids:
    if HSC_id in pre_linked_ids:
        already_linked += 1
    if HSC_id not in all_downloaded_ids:
        missing += 1
        
    if HSC_id in target_ids.HSC_id.values:
        class_path = targets_path
    elif HSC_id in contaminant_ids.HSC_id.values:
        class_path = contaminants_path
    else:
        raise ValueError("HSC id {} in neither targets nor contaminants".format(HSC_id))
        
    image_dir = google_dir / str(HSC_id)
    new_dir = class_path / image_dir.name
    if not new_dir.is_dir():
#         new_dir.symlink_to(image_dir, target_is_directory=True)
        pass
        
    num_to_link += 1
    
    
print("just linked: ", num_to_link)
print("previously linked: ", already_linked)
print("missing: ", missing)
# Out:
# just linked:  26934
# previously linked:  15413
# missing:  1655

# %% [markdown]
# # Check that the directory contents are correct

# %%
for path in targets_path.iterdir():
    if not path.is_dir():
        continue
    
    HSC_id = int(path.name)
    if HSC_id not in target_ids.HSC_id.values:
        raise ValueError("HSC id {} should not be in target path".format(HSC_id))

# %%
for path in contaminants_path.iterdir():
    if not path.is_dir():
        continue
    
    HSC_id = int(path.name)
    if HSC_id not in contaminant_ids.HSC_id.values:
        raise ValueError("HSC id {} should not be in contaminant path".format(HSC_id))
